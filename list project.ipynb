# %%
mylist = ["Tarun  ", "Anand" , "Lokesh","Vishwas" , "Arjun"]
print(mylist)
#type(mylist) #Type of data structure
#print(mylist[0])#it will show the name of index value 0
print(mylist[1:4])
mylist.append("Sumit") #it will insert at last of the index value
print(mylist)
mylist.insert(1,"Udit") #it will insert at first position
print(mylist)
mylist.append("Tarun")
print(mylist)
mylist.count("Tarun")
mylist.sort() #list ko sort karega
print(mylist)
mylist.pop(1) #it will delete the value of index (1)
print(mylist)
mylist.append(["Div" , "Mahesh"])
print(mylist)
#mylist.remove("Arjun") agar index value pata na ho to uske naam se bhi hataya ja sakta hai
# Out:
# ['Tarun  ', 'Anand', 'Lokesh', 'Vishwas', 'Arjun']
# ['Anand', 'Lokesh', 'Vishwas']
# ['Tarun  ', 'Anand', 'Lokesh', 'Vishwas', 'Arjun', 'Sumit']
# ['Tarun  ', 'Udit', 'Anand', 'Lokesh', 'Vishwas', 'Arjun', 'Sumit']
# ['Tarun  ', 'Udit', 'Anand', 'Lokesh', 'Vishwas', 'Arjun', 'Sumit', 'Tarun']
# ['Anand', 'Arjun', 'Lokesh', 'Sumit', 'Tarun', 'Tarun  ', 'Udit', 'Vishwas']
# ['Anand', 'Lokesh', 'Sumit', 'Tarun', 'Tarun  ', 'Udit', 'Vishwas']
# ['Anand', 'Lokesh', 'Sumit', 'Tarun', 'Tarun  ', 'Udit', 'Vishwas', ['Div', 'Mahesh']]

# %%
mylist = ["Tarun  ", "Anand" , "Lokesh","Vishwas" , "Arjun"]
mylist.reverse()
print(mylist)
# Out:
# ['Arjun', 'Vishwas', 'Lokesh', 'Anand', 'Tarun  ']

# %%
#isko change nahiu kiya ja sakta hai aur na hi kuchh delete kiya ja sakta hai
mytuple = ("1","2","3")
type(mytuple)
print(mytuple)
mytuple.index("1")
# Out:
# ('1', '2', '3')
# 0

# %%
type(mytuple)
# Out:
# tuple

# %%
mytuple.count("1")
# Out:
# 1

# %%
#duplicacy is not allowed 
petmy = {1,2,3,4,5}
type(petmy)
# Out:
# set

# %%
print(setmy)
# Out:
# {1, 2, 3, 4, 5}

# %%
set1 = {1,2,3}
set2 = {4,5,6}
print(set1 | set2)
print(set1 & set2)
# Out:
# {1, 2, 3, 4, 5, 6}
# set()

# %%
print(set1 & set2)
# Out:
# set()

# %%
student = {"name":"Tarun","age":18}
print(type(student))
print(Student)
# Out:
# <class 'dict'>
# {'name': 'Tarun', 'age': 18}

# %%
student.pop("name")
# Out:
# 'Tarun'

# %%
print("Tarun")
# Out:
# Tarun

# %%
text = ("Hello vgu")
print(text[0:5])
# Out:
# Hello

# %%
print(text.replace("vgu" ,"vgu guys"))
# Out:
# Hello vgu guys

# %%
text = "Hello vgu"
print(text.split())
# Out:
# ['Hello', 'vgu']

# %%
text2 = ["Hello","vgu"]
print(text2)
# Out:
# ['Hello', 'vgu']

# %%
print("        ".join(text2)) #jitna space inverted commas ke andar reh jayega utna hi ye output me Hello vgu ke bich space dega
# Out:
# Hello          vgu

# %%
file = open("my doc.txt","w")
file.writte("Hello i am written from python code")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 file = open("my doc.txt","w")
# ----> 2 file.writte("Hello i am written from python code")
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'writte'
